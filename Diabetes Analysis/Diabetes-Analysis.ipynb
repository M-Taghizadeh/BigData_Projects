# %% [markdown]
# # Diabetes Analysis: Case Studies
#
# By Mohammad Taghizadeh

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Reading the dataset

# %%
diabetes = pd.read_csv("diabetes.csv")

# %%
diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ###### This dataset is obtained from Kaggle, but originally from National Institute of Diabetes and Digestive and Kidney Diseases. The main aim of this dataset is to predict if a patient has diabetes based on the following features:
# 1. Pregnancies: Number of times pregnant
# 2. Glucose: Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# 3. BloodPressure: Diastolic blood pressure (mm Hg)
# 4. SkinThickness: Triceps skin fold thickness (mm)
# 5. Insulin: 2-Hour serum insulin (mu U/ml)
# 6. BMI: Body mass index (weight in kg/(height in m)^2)
# 7. DiabetesPedigreeFunction: Diabetes pedigree function
# 8. Age: Age (years)
# ###### In this dataset, the patients are all female and they belong to the Pima Indian heritage

# %% [markdown]
# # Exploratory Data Analysis

# %%
# summary statistics of every column in the dataset
diabetes.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
sns.set_style("darkgrid")
plt.figure(figsize = (7,5))
sns.countplot(x=diabetes['Pregnancies'], hue=diabetes['Outcome'], alpha=0.9)
# Maximum number of patients in this dataset have been pregnant once or twice.
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='count'>

# %%
plt.figure(figsize = (7,5))
sns.countplot(x=diabetes['Outcome'])
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='count'>

# %%
plt.figure(figsize = (10,7))
sns.distplot(x=diabetes['BloodPressure'], bins=10, kde=False)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (10,7))
sns.distplot(x=diabetes['Age'],bins=15, kde=False)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (10,7))
sns.scatterplot(x=diabetes['BloodPressure'], y=diabetes['Glucose'],palette="deep", hue=diabetes['Outcome'], alpha = 1)
# Out:
# <AxesSubplot:xlabel='BloodPressure', ylabel='Glucose'>

# %%
plt.figure(figsize = (10,7))
sns.heatmap(diabetes.corr(), cmap="inferno", annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (10,7))
sns.boxplot(x=diabetes['Outcome'], y=diabetes['Age'])

# The female patients who are diagnosed with diabetes tend to belong to a median age group of around 38-40 years.
# Patients who are not diagnosed with diabetes typically belong to a meadian age group of 28-30 years.
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='Age'>

# %%
plt.figure(figsize = (10,7))
sns.boxplot(x=diabetes['Outcome'], y=diabetes['DiabetesPedigreeFunction'])

# Patients who are diagnosed with diabetes tend to have around 0.45 units of the DiabetesPedigreeFunction
# Whereas patients who don't have diabetes tend to have lower Diabetes Pedigree Function
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='DiabetesPedigreeFunction'>

# %%
plt.figure(figsize = (10,7))
sns.boxplot(x=diabetes['Outcome'], y=diabetes['BMI'])

# Typically, the patients who are diagnosed with diabetes tend to have higher BMI. 
# Here it shows that for the patients who are diagnosed with diabetes, the median BMI is approx 35
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='BMI'>

# %%
plt.figure(figsize = (10,7))
sns.boxplot(x=diabetes['Outcome'], y=diabetes['Insulin'])

# Patients diagnosed with diabetes have higher amount of insulin compared to those who don't have diabetes
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='Insulin'>

# %%
plt.figure(figsize = (10,7))
sns.boxplot(x=diabetes['Outcome'], y=diabetes['SkinThickness'])

# Diabetes patients tend to have thicker skin compared to those who are not diagnosed with diabetes
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='SkinThickness'>

# %%
plt.figure(figsize = (10,7))
sns.boxplot(x=diabetes['Outcome'], y=diabetes['BloodPressure'])

# Diabetes patients tend to have higher Blood Pressure (median approx 70)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='BloodPressure'>

# %%
plt.figure(figsize = (10,7))
sns.boxplot(x=diabetes['Outcome'], y=diabetes['Glucose'])

# Patients diagnosed with diabetes tend to have higher glucose level (median of approx 130)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='Glucose'>

# %%
plt.figure(figsize = (10,7))
sns.boxplot(x=diabetes['Outcome'], y=diabetes['Pregnancies'])

# Patients who have been pregnant atleast thrice tend to have higher chance of being diabetic.
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='Pregnancies'>

# %%
sns.pairplot(diabetes, hue="Outcome", palette="deep")

# %%
plt.figure(figsize = (10,7))
sns.lmplot(data=diabetes, x="Age", y="Pregnancies",hue="Outcome")

# %%
plt.figure(figsize = (10,7))
sns.lmplot(data=diabetes, x="SkinThickness", y="Insulin", hue="Outcome")

# %%
plt.figure(figsize = (10,7))
sns.lmplot(data=diabetes, x="Age", y="BloodPressure", hue="Outcome")

# %% [markdown]
# # Data Reduction Techniques
#
# ### Using PCA

# %%
x=diabetes.iloc[:,0:8]
x.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
y=diabetes['Outcome']
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
# Scaling the data
from sklearn.preprocessing import StandardScaler
x = StandardScaler().fit_transform(x)

# %%
features = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin','BMI','DiabetesPedigreeFunction','Age' ]
x = pd.DataFrame(data=x, columns=features)
x.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.639947  0.848324       0.149641       0.907270 -0.692891  0.204013
# 1    -0.844885 -1.123396      -0.160546       0.530902 -0.692891 -0.684422
# 2     1.233880  1.943724      -0.263941      -1.288212 -0.692891 -1.103255
# 3    -0.844885 -0.998208      -0.160546       0.154533  0.123302 -0.494043
# 4    -1.141852  0.504055      -1.504687       0.907270  0.765836  1.409746
#
#    DiabetesPedigreeFunction       Age
# 0                  0.468492  1.425995
# 1                 -0.365061 -0.190672
# 2                  0.604397 -0.105584
# 3                 -0.920763 -1.041549
# 4                  5.484909 -0.020496

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)

# %%
principalComponents = pca.fit_transform(x)

# %%
principalDf = pd.DataFrame(data=principalComponents, columns=['Principal Component 1', 'Principal Component 2'])

# %%
principalDf.head(5)
# Out:
#    Principal Component 1  Principal Component 2
# 0               1.068503               1.234895
# 1              -1.121683              -0.733852
# 2              -0.396477               1.595876
# 3              -1.115781              -1.271241
# 4               2.359334              -2.184819

# %%
diabetes['Outcome'].head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
finalDf = pd.concat([principalDf, diabetes['Outcome']], axis = 1)
finalDf.head(5)
# Out:
#    Principal Component 1  Principal Component 2  Outcome
# 0               1.068503               1.234895        1
# 1              -1.121683              -0.733852        0
# 2              -0.396477               1.595876        1
# 3              -1.115781              -1.271241        0
# 4               2.359334              -2.184819        1

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 Component PCA', fontsize = 20)

targets = [0, 1]
colors = ['r', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['Outcome'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'Principal Component 1']
               , finalDf.loc[indicesToKeep, 'Principal Component 2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %% [markdown]
# # Different algorithms for prediction:
#
# #### 1. K-Nearest Neighbors

# %%
# Loading the packages
from sklearn.neighbors import KNeighborsClassifier
import sklearn.metrics
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
# Splitting the data into taining and testing
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.40) # 60% training and 40% testing

# %%
# KNN
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(X_train,y_train)
y_pred = knn.predict(X_test)

# %%
print("Training Score =", knn.score(X_train, y_train))
print("Testing Score =", knn.score(X_test, y_test)) 
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("Classification Report:")
print("Accuracy Score for 10 neighbors= ", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Training Score = 0.7978260869565217
# Testing Score = 0.7175324675324676
# Confusion Matrix:
# [[182  24]
#  [ 63  39]]
# Classification Report:
# Accuracy Score for 10 neighbors=  0.7175324675324676
#               precision    recall  f1-score   support
#
#            0       0.74      0.88      0.81       206
#            1       0.62      0.38      0.47       102
#
#     accuracy                           0.72       308
#    macro avg       0.68      0.63      0.64       308
# weighted avg       0.70      0.72      0.70       308
